# %% [markdown]
# # 2D Griffith Crack example (2DP0)

# %% [markdown]
# When the displacement boundary conditions are specified as follows,
# $$
# D(x) = {2 (1-\nu) \sigma_A \over G} \sqrt{a^2 - x^2}
# $$
#
# The traction solution for the Griffith crack case is given as seen in Weertman (1996) as,
# $$
# t(x) =
#     \begin{cases}
#         \sigma_A & \text{if } x \leq |a|\\
#         0 & \text{if } x > |a|
#     \end{cases}
# $$

# %%
import numpy as np
import sys
import os
np.set_printoptions(precision=5, suppress=True)
import matplotlib.pyplot as plt
from matplotlib import ticker, cm, colors

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams['figure.figsize'] = [3.5, 3.5]
plt.rcParams['font.size'] = 12
#plt.rcParams['text.usetex']=True
plt.rcParams["savefig.bbox"] = "tight"
plt.rcParams["savefig.pad_inches"] = 0.1
plt.rcParams["savefig.dpi"] = 100
#plt.rcParams["text.latex.preamble"] =r'\usepackage{amsmath}'+ r'\usepackage{amssymb}' + r'\usepackage{accents}'+ r'\usepackage{bm}'+ r'\boldmath'+ r'\renewcommand{\v}[1]{\boldsymbol{{#1}}}'+ r'\DeclareRobustCommand{\sot}[1]{\boldsymbol{{#1}}}'

norm1 = lambda a : np.linalg.norm(a, axis=1)
norm = lambda a : np.linalg.norm(a)

home = os.environ['HOME'] 
# sys.path.append(home + "/geolab/dev_bigwham/build/interfaces/python")
# from bigwham4py import Hmatrix  # linear operator file

sys.path.append(home + "/Desktop/GEL/BigWham/build/interfaces/python")
from hmatrix import Hmatrix  # linear operator file

# %%
pressure = 1.0

G = 1.0
nu = 0.25
E = (2 * G) * (1 + nu)
sigma_A = 1.0

pre_fac = 2*((1 - nu)/G)

# Mesh
a = 1.0
nelts = 100
coor1D = np.linspace(-a, a, nelts + 1)
coor = np.transpose(np.array([coor1D, coor1D * 0.0]))
conn = np.fromfunction(lambda i, j: i + j, (nelts, 2), dtype=np.int_)

# H-matrix parameter
max_leaf_size=100
eta=3.
eps_aca=1.e-4

# Hmatrix
kernel = "2DP0"
elas_prop = np.array([E, nu])
hmat = Hmatrix(kernel, coor, conn, elas_prop, max_leaf_size, eta, eps_aca)

col_pts = hmat.getMeshCollocationPoints()
# Out:
#  Now setting things for kernel ... 2DP0 with properties size 2
# Cluster tree creation time :  0
# Time for binary cluster tree construction  5.01e-07
# Binary cluster tree depth = 0
# Number of blocks = 1
# Number of full blocks = 1
# Number of low rank blocks = 0
# Pattern Created
#  Loop on full blocks construction
#  N full blocks 1
# Loop on low rank blocks construction
# N low rank blocks 0
# dof_dimension: 2
# Creation of hmat done in 0.0236972
# Compression ratio - 1
# Hmat object - built
# HMAT --> built
# HMAT set, CR = 1, eps_aca = 0.0001, eta = 3
# BigWhamIO ENDED

# %%
dd = np.zeros(col_pts.shape)
dd[:, 1] = pre_fac * np.sqrt(a**2 - col_pts[:, 0]**2)

# calculate tractions
t = hmat.matvec(dd.flatten())

t_anal = np.zeros(col_pts.shape)
t_anal[:, 1] = pressure

# %%
plt.plot(col_pts[:, 0], dd[:, 1], '.')
plt.title("Displacement BCs")
plt.xlabel("Position along crack")
plt.ylabel("Displacement")
plt.show()

# %%
plt.plot(col_pts[:, 0], t.reshape(-1, 2)[:, 1], ".")
plt.plot(col_pts[:, 0], t_anal[:, 1])
plt.legend(["Numerical", "Analytical"])
# plt.xlim([-1 - 10 * 2 * c / nelts, -1 + 10 * 2 * c / nelts])
plt.title("Traction solution")
plt.xlabel("Position along crack")
plt.ylabel("Traction")
plt.xlim([-1.5, 1.5])
# Out:
# (-1.5, 1.5)

# %%
rel_err = np.linalg.norm(t - t_anal.flatten()) / t.shape[0]
print("L2 Rel error {}".format(rel_err))
# Out:
# L2 Rel error 0.012092229931260745

# %%
pressure = 1.0

G = 1.0
nu = 0.25
E = (2 * G) * (1 + nu)
sigma_A = 1.0

pre_fac = 2*((1 + nu)/G)

nelts_array = [10**i for i in range(1, 6)]
rel_error_array = []

# H-matrix parameter
max_leaf_size = 100
eta = 3.
eps_aca = 1.e-4

for nelts in nelts_array:
    # Mesh
    a = 10
    coor1D = np.linspace(-a, a, nelts + 1)
    coor = np.transpose(np.array([coor1D, coor1D * 0.0]))
    conn = np.fromfunction(lambda i, j: i + j, (nelts, 2), dtype=np.int_)

    # Hmatrix
    kernel = "2DP0"
    elas_prop = np.array([E, nu])
    hmat = Hmatrix(kernel, coor, conn, elas_prop, max_leaf_size, eta, eps_aca)

    col_pts = hmat.getMeshCollocationPoints()

    dd = np.zeros(col_pts.shape)
    dd[:, 1] = pre_fac * np.sqrt(a**2 - col_pts[:, 0]**2)

    # calculate tractions
    t = hmat.matvec(dd.flatten())

    t_anal = np.zeros(col_pts.shape)
    t_anal[:, 1] = pressure

    rel_err = np.linalg.norm(t - t_anal.flatten()) / t.shape[0]
    print("L2 Rel error {}".format(rel_err))
    rel_error_array.append(rel_err)
# Out:
# L2 Rel error 0.09220475585638874
#  Now setting things for kernel ... 2DP0 with properties size 2
# Cluster tree creation time :  0
# Time for binary cluster tree construction  3.81e-07
# Binary cluster tree depth = 0
# Number of blocks = 1
# Number of full blocks = 1
# Number of low rank blocks = 0
# Pattern Created
#  Loop on full blocks construction
#  N full blocks 1
# Loop on low rank blocks construction
# N low rank blocks 0
# dof_dimension: 2
# Creation of hmat done in 0.00182524
# Compression ratio - 1
# Hmat object - built
# HMAT --> built
# HMAT set, CR = 1, eps_aca = 0.0001, eta = 3
# BigWhamIO ENDED
#  Now setting things for kernel ... 2DP0 with properties size 2
# Cluster tree creation time :  0
# Time for binary cluster tree construction  2.01e-07
# Binary cluster tree depth = 0
# Number of blocks = 1
# Number of full blocks = 1
# Number of low rank blocks = 0
# Pattern Created
#  Loop on full blocks construction
#  N full blocks 1
# Loop on low rank blocks construction
# N low rank blocks 0
# dof_dimension: 2
# Creation of hmat done in 0.00448255
# Compression ratio - 1
# Hmat object - built
# HMAT --> built
# HMAT set, CR = 1, eps_aca = 0.0001, eta = 3
# BigWhamIO ENDED
# L2 Rel error 0.03610335389762515
#  Now setting things for kernel ... 2DP0 with properties size 2
# Cluster tree creation time :  0
# Time for binary cluster tree construction  7.612e-05
# Binary cluster tree depth = 4
# Number of blocks = 112
# Number of full blocks = 46
# Number of low rank blocks = 66
# Pattern Created
#  Loop on full blocks construction
#  N full blocks 46
# Loop on low rank blocks construction
# N low rank blocks 66
# dof_dimension: 2
# Creation of hmat done in 0.0319929
# Compression ratio - 0.239186
# Hmat object - built
# HMAT --> built
# HMAT set, CR = 0.239186, eps_aca = 0.0001, eta = 3
# BigWhamIO ENDED
# L2 Rel error 0.01203807879206215
#  Now setting things for kernel ... 2DP0 with properties size 2
# Cluster tree creation time :  0
# Time for binary cluster tree construction  0.000823454
# Binary cluster tree depth = 7
# Number of blocks = 1102
# Number of full blocks = 382
# Number of low rank blocks = 720
# Pattern Created
#  Loop on full blocks construction
#  N full blocks 382
# Loop on low rank blocks construction
# N low rank blocks 720
# dof_dimension: 2
# Creation of hmat done in 0.341358
# Compression ratio - 0.0373597
# Hmat object - built
# HMAT --> built
# HMAT set, CR = 0.0373597, eps_aca = 0.0001, eta = 3
# BigWhamIO ENDED
# L2 Rel error 0.0038669931756116958
#  Now setting things for kernel ... 2DP0 with properties size 2
# Cluster tree creation time :  0
# Time for binary cluster tree construction  0.0122365
# Binary cluster tree depth = 10
# Number of blocks = 9148
# Number of full blocks = 3070
# Number of low rank blocks = 6078
# Pattern Created
#  Loop on full blocks construction
#  N full blocks 3070
# Loop on low rank blocks construction
# N low rank blocks 6078
# dof_dimension: 2
# Creation of hmat done in 5.15966
# Compression ratio - 0.00516834
# Hmat object - built
# HMAT --> built
# HMAT set, CR = 0.00516834, eps_aca = 0.0001, eta = 3
# BigWhamIO ENDED
# L2 Rel error 0.0012288180644591368

# %%
plt.figure()
plt.plot(nelts_array, rel_error_array)
plt.title("Relative error vs nelts")
plt.xlabel("nelts")
plt.ylabel("L2 relative error")
#saves fig - remember to remove
#plt.savefig('rel_err_h.png', dpi=100, bbox_inches='tight')
plt.show()

# %%
h_array = [1/nelts for nelts in nelts_array]

plt.figure()
plt.plot(h_array, rel_error_array)
plt.title("Relative error vs h")
plt.xlabel("h")
plt.ylabel("L2 relative error")
#saves fig - remember to remove
#plt.savefig('rel_err_h.png', dpi=100, bbox_inches='tight')
plt.show()

# %%
plt.figure()
plt.plot(h_array, rel_error_array)
plt.title("Log10 of relative error")
plt.xlabel("Number of elements")
plt.ylabel("L2 relative error")
plt.yscale('log')
plt.xscale('log')
#saves fig - remember to remove
#plt.savefig('log_rel_err_h.png', dpi=100, bbox_inches='tight')
plt.show()

# %%
print(h_array)
print(rel_error_array)
# Out:
# [0.1, 0.01, 0.001, 0.0001, 1e-05]
# [0.09220475585638874, 0.03610335389762515, 0.01203807879206215, 0.0038669931756116958, 0.0012288180644591368]

# %%
log_h = np.log(np.asarray(nelts_array)[2:])
log_rel_array = np.log(np.asarray(rel_error_array)[2:])

m, c = np.polyfit(log_h, log_rel_array, 1)

print(m)
print(c)
# Out:
# -0.4955347971999641
# -0.9948428338029287

# %%
plt.figure()
plt.plot(nelts_array, rel_error_array, "*-")
plt.plot(nelts_array, 0.5*np.array(nelts_array) ** (-0.5) , "--")
plt.title("Convergence for Griffith crack")
plt.text(1000, 0.007, r'$m$' + ' = -0.5', rotation=-42)
plt.legend(["Numerical error", "-0.5 slope line"])
plt.xlabel("Number of elements")
plt.ylabel("L2 relative error")
plt.yscale('log',base=10)
plt.xscale('log',base=10)
#saves fig - remember to remove
# plt.savefig('log2_rel_err_h.png', dpi=100, bbox_inches='tight')
# plt.show()
