# %%
# %run generate_penny_mesh.py 0.005
# Out:
# Number of points 148575
# Number of Elements 290863

# %%
# %run generate_penny_mesh.py 0.01
# Out:
# Number of points 20384
# Number of Elements 9348

# %%
# %run generate_penny_mesh.py 0.025
# Out:
# Number of points 6521
# Number of Elements 11780

# %%
# %run generate_penny_mesh.py 0.05
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/miniconda3/lib/python3.10/site-packages/IPython/core/magics/execution.py:701, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     700     fpath = arg_lst[0]
# --> 701     filename = file_finder(fpath)
#     702 except IndexError as e:
#
# File ~/miniconda3/lib/python3.10/site-packages/IPython/utils/path.py:90, in get_py_filename(name)
#      89         return py_name
# ---> 90 raise IOError("File `%r` not found." % name)
#
# OSError: File `'generate_penny_mesh.py'` not found.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 get_ipython().run_line_magic('run', 'generate_penny_mesh.py 0.05')
#
# ...

# %%
# %run generate_penny_mesh.py 0.1

# %%
# %run generate_penny_mesh.py 0.25

# %%
# %run generate_penny_mesh.py 0.5
